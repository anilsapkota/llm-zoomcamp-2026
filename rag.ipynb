# %%
from rag_helper import RAGBase
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from rag_helper import RAGBase
#
# ImportError: cannot import name 'RAGBase' from 'rag_helper' (/workspaces/llm-zoomcamp-2026/rag_helper.py)
